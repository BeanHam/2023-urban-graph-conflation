# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss00001 = np.load('logs/DuoGraph_0.0001.npy')
loss0001 = np.load('logs/DuoGraph_0.001.npy')
loss001 = np.load('logs/DuoGraph_0.01.npy')
plt.plot(loss00001)
plt.plot(loss0001)
plt.plot(loss001)
pass

# %%
loss0001
# Out:
# array([0.97724128, 0.97724116, 0.97724116, 0.97724115, 0.97724111])

# %%
loss0001 = np.load('logs/SingleGraph_0.001.npy')
plt.plot(loss0001)
pass
