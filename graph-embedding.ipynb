# %%
import numpy as np
import networkx as nx
from karateclub import FeatherGraph, GraphSetReader, Diff2Vec

# %%
reader = GraphSetReader("twitch")
graphs = reader.get_graphs()
y = reader.get_target()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 reader = GraphSetReader("twitch")
# ----> 2 graphs = reader.get_graphs()
#       3 y = reader.get_target()
#
# File /opt/anaconda3/lib/python3.8/site-packages/karateclub/dataset/dataset_reader.py:121, in GraphSetReader.get_graphs(self)
#     115 def get_graphs(self) -> List[nx.classes.graph.Graph]:
#     116     r"""Getting the graphs.
#     117
#     118     Return types:
#     119         * **graphs** *(List of NetworkX graphs)* - Graphs of interest.
#     120     """
# --> 121     graphs = self._dataset_reader("graphs.json")
#     122     graphs = json.loads(graphs.decode())
#     123     graphs = [nx.from_edgelist(graphs[str(i)]) for i in range(len(graphs))]
#
# File /opt/anaconda3/lib/python3.8/site-packages/karateclub/dataset/dataset_reader.py:112, in GraphSetReader._dataset_reader(self, end)
#     108 """
#     109 Reading the dataset from the web.
#     110 """
#     111 path = self.base_url + self.dataset + "/" + end
# --> 112 data = urllib.request.urlopen(path).read()
#     113 return data
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     637 # According to RFC 2616, "2xx" code indicates that the client's
#     638 # request was successfully received, understood, and accepted.
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:569, in OpenerDirector.error(self, proto, *args)
#     567 if http_err:
#     568     args = (dict, 'default', 'http_error_default') + orig_args
# --> 569     return self._call_chain(*args)
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /opt/anaconda3/lib/python3.8/urllib/request.py:649, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     648 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
nx.draw(graphs[102])

# %%
model = Diff2Vec(diffusion_number=2, diffusion_cover=20, dimensions=16)
model.fit(graphs[0])
X = model.get_embedding()

# %%
X.shape

# %%
model.fit(graphs)

# %%
X = model.get_embedding()

# %%
X.shape
# Out:
# (10000, 500)
